# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
imageName = 'image062-roi2.tif'

# %%
ann = Image.open(f'Aug/annotations/center_{imageName}')
img = Image.open(f'Aug/images/center_{imageName}')

fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(ann)
ax[1].imshow(img)

# %%
ann = Image.open(f'Aug/annotations/gaussian_{imageName}')
img = Image.open(f'Aug/images/gaussian_{imageName}')

fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(ann)
ax[1].imshow(img)

# %%
ann = Image.open(f'Aug/annotations/salt_and_pepper_{imageName}')
img = Image.open(f'Aug/images/salt_and_pepper_{imageName}')

fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(ann)
ax[1].imshow(img)

# %%
ann = Image.open(f'Aug/annotations/rotated_{imageName}')
img = Image.open(f'Aug/images/rotated_{imageName}')

fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(ann)
ax[1].imshow(img)

# %%
ann = Image.open(f'Aug/annotations/{imageName}')
img = Image.open(f'Aug/images/{imageName}')

fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(ann)
ax[1].imshow(img)
