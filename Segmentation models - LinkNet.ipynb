# %%
#!pip install git+https://github.com/qubvel/segmentation_models

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import os
import cv2
from tensorflow import keras
import numpy as np
import PIL
from IPython.display import Image, display
from PIL import ImageOps
import random
import re
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
sm.set_framework('tf.keras')

sm.framework()
# Out:
# 'tf.keras'

# %%
def bgr_to_rgb(img):
    b,g,r = cv2.split(img)
    return cv2.merge([r,g,b])

# %%
def load_all_imgs(path, img_size, mode):
    imgs = []
    files = os.listdir(path)
    files.sort()
    print(f'\n{path} found {len(files)} img to load')
    for index, file in enumerate(files):
        img_path = os.path.join(path, file)
        img = cv2.imread(img_path, mode)
        
        if mode == 0:
            img = np.expand_dims(img, 2)
        
        if mode == 1:
            img = bgr_to_rgb(img)
        img = cv2.resize(img, img_size)
        img = img / 255.
        imgs.append(img)
        if index % 100 == 0:
            print(f'\n[{index}]:', end='')
        else:
            print("|", end='')
    return np.array(imgs)

# %%
img_size = (224, 224)
img_shape = (224,224,3)
input_dir = "../dataset/segmentation/all_seg/"
target_dir = "../dataset/segmentation/annotation/all/"
num_classes = 1
batch_size = 10
epochs = 100

# %%
# Load images
trainImgs = load_all_imgs(input_dir,img_size, 1)
validImgs = load_all_imgs(target_dir,img_size, 0)
# Out:
# ../dataset/segmentation/all_seg/ found 120 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||
# ../dataset/segmentation/annotation/all/ found 120 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||

# %%
img_to_test = int(len(trainImgs) * 0.8)
x_train = trainImgs[0:img_to_test]
y_train = validImgs[0:img_to_test]
x_val = trainImgs[img_to_test:]
y_val = validImgs[img_to_test:]
validation_data = (x_val, y_val)
print("ImgToTest:",img_to_test)
print("Validation_data_size:", len(validation_data[0]))
# Out:
# ImgToTest: 96
# Validation_data_size: 24

# %%
keras.backend.clear_session()

# %%
model = sm.Linknet(input_shape=img_shape, classes=1, encoder_freeze=True)
model.compile('Adam',loss=sm.losses.bce_jaccard_loss,metrics=[sm.metrics.iou_score])
# Out:
# 2021-11-24 20:30:36.397107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.401192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.401455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.402467: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-24 20:30:36.403034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.403325: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.403550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.724481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.724726: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.724930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-24 20:30:36.725206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2998 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
pred = model.predict(x_train)
# Out:
# 2021-11-24 20:30:37.398867: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-11-24 20:30:37.936164: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8204
# 2021-11-24 20:30:38.962365: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.46GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-24 20:30:38.962466: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-24 20:30:39.062224: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.74GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-24 20:30:42.316666: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-24 20:30:45.493306: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-24 20:30:48.633338: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.

# %%
plt.imshow(pred[80], cmap='gray')

# %%
from matplotlib.colors import NoNorm
predict_img = pred[80]
predict_img[predict_img > 0.5] = 1
predict_img[predict_img <= 0.5] = 0

plt.imshow(predict_img, cmap='gray', norm=NoNorm())

# %%
model.fit(x_train, y_train, batch_size=batch_size,epochs=epochs, validation_data=validation_data)
# Out:
# Epoch 1/100
# 2021-11-24 20:30:54.161667: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.35GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#  9/10 [==========================>...] - ETA: 0s - loss: 1.3574 - iou_score: 0.2879
# 2021-11-24 20:31:02.691614: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.22GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-24 20:31:03.448949: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-24 20:31:04.151262: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 10/10 [==============================] - 18s 1s/step - loss: 1.3481 - iou_score: 0.2931 - val_loss: 1.9557 - val_iou_score: 0.2933
# Epoch 2/100
# 10/10 [==============================] - 3s 319ms/step - loss: 1.1437 - iou_score: 0.3683 - val_loss: 1.9537 - val_iou_score: 0.3299
# Epoch 3/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.9770 - iou_score: 0.4465 - val_loss: 1.7154 - val_iou_score: 0.2884
# Epoch 4/100
# 10/10 [==============================] - 3s 291ms/step - loss: 0.8490 - iou_score: 0.5194 - val_loss: 2.5144 - val_iou_score: 0.2652
# Epoch 5/100
# 10/10 [==============================] - 3s 295ms/step - loss: 0.7755 - iou_score: 0.5666 - val_loss: 4.0369 - val_iou_score: 0.0928
# Epoch 6/100
# 10/10 [==============================] - 3s 309ms/step - loss: 0.7179 - iou_score: 0.6023 - val_loss: 2.2372 - val_iou_score: 0.3200
# Epoch 7/100
# 10/10 [==============================] - 3s 302ms/step - loss: 0.6923 - iou_score: 0.6193 - val_loss: 3.2281 - val_iou_score: 0.1570
# Epoch 8/100
# 10/10 [==============================] - 3s 305ms/step - loss: 0.6595 - iou_score: 0.6349 - val_loss: 2.3581 - val_iou_score: 0.2799
# Epoch 9/100
# 10/10 [==============================] - 3s 309ms/step - loss: 0.6334 - iou_score: 0.6477 - val_loss: 2.0813 - val_iou_score: 0.2739
# Epoch 10/100
# 10/10 [==============================] - 3s 302ms/step - loss: 0.5997 - iou_score: 0.6663 - val_loss: 1.0939 - val_iou_score: 0.4637
# Epoch 11/100
# 10/10 [==============================] - 3s 303ms/step - loss: 0.5788 - iou_score: 0.6784 - val_loss: 1.4450 - val_iou_score: 0.3904
# Epoch 12/100
# 10/10 [==============================] - 3s 307ms/step - loss: 0.5573 - iou_score: 0.6909 - val_loss: 1.0742 - val_iou_score: 0.4698
# Epoch 13/100
# 10/10 [==============================] - 3s 313ms/step - loss: 0.5387 - iou_score: 0.7002 - val_loss: 1.0468 - val_iou_score: 0.4817
# Epoch 14/100
# 10/10 [==============================] - 3s 313ms/step - loss: 0.5177 - iou_score: 0.7121 - val_loss: 1.0500 - val_iou_score: 0.4803
# Epoch 15/100
# 10/10 [==============================] - 3s 309ms/step - loss: 0.4950 - iou_score: 0.7248 - val_loss: 1.0964 - val_iou_score: 0.4710
# Epoch 16/100
# 10/10 [==============================] - 3s 315ms/step - loss: 0.4742 - iou_score: 0.7367 - val_loss: 0.9757 - val_iou_score: 0.5023
# Epoch 17/100
# 10/10 [==============================] - 3s 299ms/step - loss: 0.4684 - iou_score: 0.7391 - val_loss: 1.0312 - val_iou_score: 0.4889
# Epoch 18/100
# 10/10 [==============================] - 3s 299ms/step - loss: 0.4584 - iou_score: 0.7465 - val_loss: 0.9879 - val_iou_score: 0.4988
# Epoch 19/100
# 10/10 [==============================] - 3s 303ms/step - loss: 0.4561 - iou_score: 0.7495 - val_loss: 0.9794 - val_iou_score: 0.4970
# Epoch 20/100
# 10/10 [==============================] - 3s 302ms/step - loss: 0.4440 - iou_score: 0.7536 - val_loss: 0.9642 - val_iou_score: 0.5041
# Epoch 21/100
# 10/10 [==============================] - 3s 305ms/step - loss: 0.4171 - iou_score: 0.7683 - val_loss: 1.0052 - val_iou_score: 0.4964
# Epoch 22/100
# 10/10 [==============================] - 3s 298ms/step - loss: 0.4009 - iou_score: 0.7747 - val_loss: 1.0207 - val_iou_score: 0.4972
# Epoch 23/100
# 10/10 [==============================] - 3s 303ms/step - loss: 0.3912 - iou_score: 0.7804 - val_loss: 0.9633 - val_iou_score: 0.5093
# Epoch 24/100
# 10/10 [==============================] - 3s 303ms/step - loss: 0.3760 - iou_score: 0.7893 - val_loss: 1.0047 - val_iou_score: 0.4989
# Epoch 25/100
# 10/10 [==============================] - 3s 304ms/step - loss: 0.3761 - iou_score: 0.7904 - val_loss: 1.0137 - val_iou_score: 0.5008
# Epoch 26/100
# 10/10 [==============================] - 3s 304ms/step - loss: 0.3611 - iou_score: 0.7981 - val_loss: 0.9749 - val_iou_score: 0.5159
# Epoch 27/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.3593 - iou_score: 0.7998 - val_loss: 1.0022 - val_iou_score: 0.5114
# Epoch 28/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.3422 - iou_score: 0.8077 - val_loss: 1.0236 - val_iou_score: 0.5070
# Epoch 29/100
# 10/10 [==============================] - 3s 292ms/step - loss: 0.3355 - iou_score: 0.8108 - val_loss: 1.0849 - val_iou_score: 0.5037
# Epoch 30/100
# 10/10 [==============================] - 3s 292ms/step - loss: 0.3317 - iou_score: 0.8147 - val_loss: 1.0766 - val_iou_score: 0.5006
# Epoch 31/100
# 10/10 [==============================] - 3s 292ms/step - loss: 0.3112 - iou_score: 0.8237 - val_loss: 1.0537 - val_iou_score: 0.5101
# Epoch 32/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.3024 - iou_score: 0.8291 - val_loss: 1.0918 - val_iou_score: 0.5060
# Epoch 33/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.3008 - iou_score: 0.8303 - val_loss: 1.0436 - val_iou_score: 0.5166
# Epoch 34/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.3064 - iou_score: 0.8301 - val_loss: 1.0907 - val_iou_score: 0.5054
# Epoch 35/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.3021 - iou_score: 0.8312 - val_loss: 1.1085 - val_iou_score: 0.5109
# Epoch 36/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.2980 - iou_score: 0.8341 - val_loss: 1.1686 - val_iou_score: 0.4990
# Epoch 37/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.2820 - iou_score: 0.8397 - val_loss: 1.1061 - val_iou_score: 0.5143
# Epoch 38/100
# 10/10 [==============================] - 3s 302ms/step - loss: 0.2877 - iou_score: 0.8379 - val_loss: 1.2087 - val_iou_score: 0.4951
# Epoch 39/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.2752 - iou_score: 0.8441 - val_loss: 1.1276 - val_iou_score: 0.5132
# Epoch 40/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.2745 - iou_score: 0.8461 - val_loss: 1.1584 - val_iou_score: 0.5063
# Epoch 41/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.2749 - iou_score: 0.8447 - val_loss: 1.1492 - val_iou_score: 0.5127
# Epoch 42/100
# 10/10 [==============================] - 3s 299ms/step - loss: 0.2718 - iou_score: 0.8469 - val_loss: 1.1363 - val_iou_score: 0.5124
# Epoch 43/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.2581 - iou_score: 0.8534 - val_loss: 1.1362 - val_iou_score: 0.5113
# Epoch 44/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.2571 - iou_score: 0.8548 - val_loss: 1.1497 - val_iou_score: 0.5105
# Epoch 45/100
# 10/10 [==============================] - 3s 295ms/step - loss: 0.2460 - iou_score: 0.8607 - val_loss: 1.2167 - val_iou_score: 0.5021
# Epoch 46/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.2456 - iou_score: 0.8610 - val_loss: 1.2170 - val_iou_score: 0.5043
# Epoch 47/100
# 10/10 [==============================] - 3s 295ms/step - loss: 0.2324 - iou_score: 0.8667 - val_loss: 1.2773 - val_iou_score: 0.4980
# Epoch 48/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.2349 - iou_score: 0.8666 - val_loss: 1.1894 - val_iou_score: 0.5076
# Epoch 49/100
# 10/10 [==============================] - 3s 300ms/step - loss: 0.2406 - iou_score: 0.8643 - val_loss: 1.1972 - val_iou_score: 0.5122
# Epoch 50/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.2311 - iou_score: 0.8693 - val_loss: 1.1891 - val_iou_score: 0.5131
# Epoch 51/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.2302 - iou_score: 0.8695 - val_loss: 1.2151 - val_iou_score: 0.5121
# Epoch 52/100
# 10/10 [==============================] - 3s 303ms/step - loss: 0.2187 - iou_score: 0.8747 - val_loss: 1.1938 - val_iou_score: 0.5136
# Epoch 53/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.2196 - iou_score: 0.8748 - val_loss: 1.1931 - val_iou_score: 0.5187
# Epoch 54/100
# 10/10 [==============================] - 3s 300ms/step - loss: 0.2205 - iou_score: 0.8750 - val_loss: 1.2434 - val_iou_score: 0.5121
# Epoch 55/100
# 10/10 [==============================] - 3s 303ms/step - loss: 0.2126 - iou_score: 0.8791 - val_loss: 1.2090 - val_iou_score: 0.5151
# Epoch 56/100
# 10/10 [==============================] - 3s 295ms/step - loss: 0.2161 - iou_score: 0.8776 - val_loss: 1.3599 - val_iou_score: 0.4980
# Epoch 57/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.2174 - iou_score: 0.8757 - val_loss: 1.2463 - val_iou_score: 0.5133
# Epoch 58/100
# 10/10 [==============================] - 3s 301ms/step - loss: 0.2103 - iou_score: 0.8805 - val_loss: 1.3285 - val_iou_score: 0.5066
# Epoch 59/100
# 10/10 [==============================] - 3s 317ms/step - loss: 0.2210 - iou_score: 0.8764 - val_loss: 1.2144 - val_iou_score: 0.5143
# Epoch 60/100
# 10/10 [==============================] - 3s 319ms/step - loss: 0.2176 - iou_score: 0.8760 - val_loss: 1.2530 - val_iou_score: 0.5153
# Epoch 61/100
# 10/10 [==============================] - 3s 319ms/step - loss: 0.2160 - iou_score: 0.8783 - val_loss: 1.2256 - val_iou_score: 0.5183
# Epoch 62/100
# 10/10 [==============================] - 3s 318ms/step - loss: 0.2139 - iou_score: 0.8788 - val_loss: 1.2719 - val_iou_score: 0.5120
# Epoch 63/100
# 10/10 [==============================] - 3s 319ms/step - loss: 0.2082 - iou_score: 0.8819 - val_loss: 1.2804 - val_iou_score: 0.5121
# Epoch 64/100
# 10/10 [==============================] - 3s 317ms/step - loss: 0.2006 - iou_score: 0.8842 - val_loss: 1.2720 - val_iou_score: 0.5132
# Epoch 65/100
# 10/10 [==============================] - 3s 295ms/step - loss: 0.2013 - iou_score: 0.8835 - val_loss: 1.2764 - val_iou_score: 0.5140
# Epoch 66/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.1946 - iou_score: 0.8889 - val_loss: 1.3527 - val_iou_score: 0.5068
# Epoch 67/100
# 10/10 [==============================] - 3s 311ms/step - loss: 0.2078 - iou_score: 0.8831 - val_loss: 1.3227 - val_iou_score: 0.5079
# Epoch 68/100
# 10/10 [==============================] - 3s 300ms/step - loss: 0.1946 - iou_score: 0.8886 - val_loss: 1.2791 - val_iou_score: 0.5138
# Epoch 69/100
# 10/10 [==============================] - 3s 299ms/step - loss: 0.1960 - iou_score: 0.8887 - val_loss: 1.3123 - val_iou_score: 0.5071
# Epoch 70/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.1901 - iou_score: 0.8918 - val_loss: 1.3357 - val_iou_score: 0.5072
# Epoch 71/100
# 10/10 [==============================] - 3s 310ms/step - loss: 0.1842 - iou_score: 0.8945 - val_loss: 1.3481 - val_iou_score: 0.5047
# Epoch 72/100
# 10/10 [==============================] - 3s 302ms/step - loss: 0.1862 - iou_score: 0.8938 - val_loss: 1.3247 - val_iou_score: 0.5127
# Epoch 73/100
# 10/10 [==============================] - 3s 302ms/step - loss: 0.1923 - iou_score: 0.8900 - val_loss: 1.3070 - val_iou_score: 0.5092
# Epoch 74/100
# 10/10 [==============================] - 3s 300ms/step - loss: 0.1851 - iou_score: 0.8942 - val_loss: 1.3523 - val_iou_score: 0.5075
# Epoch 75/100
# 10/10 [==============================] - 3s 303ms/step - loss: 0.1841 - iou_score: 0.8951 - val_loss: 1.3575 - val_iou_score: 0.5112
# Epoch 76/100
# 10/10 [==============================] - 3s 308ms/step - loss: 0.1788 - iou_score: 0.8981 - val_loss: 1.3097 - val_iou_score: 0.5160
# Epoch 77/100
# 10/10 [==============================] - 3s 307ms/step - loss: 0.1804 - iou_score: 0.8974 - val_loss: 1.3836 - val_iou_score: 0.5052
# Epoch 78/100
# 10/10 [==============================] - 3s 304ms/step - loss: 0.1781 - iou_score: 0.8985 - val_loss: 1.3503 - val_iou_score: 0.5095
# Epoch 79/100
# 10/10 [==============================] - 3s 301ms/step - loss: 0.1723 - iou_score: 0.9009 - val_loss: 1.3336 - val_iou_score: 0.5110
# Epoch 80/100
# 10/10 [==============================] - 3s 306ms/step - loss: 0.1727 - iou_score: 0.9008 - val_loss: 1.3766 - val_iou_score: 0.5075
# Epoch 81/100
# 10/10 [==============================] - 3s 300ms/step - loss: 0.1733 - iou_score: 0.8993 - val_loss: 1.3163 - val_iou_score: 0.5145
# Epoch 82/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.1744 - iou_score: 0.9009 - val_loss: 1.3815 - val_iou_score: 0.5134
# Epoch 83/100
# 10/10 [==============================] - 3s 299ms/step - loss: 0.1711 - iou_score: 0.9031 - val_loss: 1.3723 - val_iou_score: 0.5083
# Epoch 84/100
# 10/10 [==============================] - 3s 301ms/step - loss: 0.1627 - iou_score: 0.9065 - val_loss: 1.3515 - val_iou_score: 0.5109
# Epoch 85/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.1678 - iou_score: 0.9043 - val_loss: 1.3726 - val_iou_score: 0.5075
# Epoch 86/100
# 10/10 [==============================] - 3s 305ms/step - loss: 0.1624 - iou_score: 0.9070 - val_loss: 1.3560 - val_iou_score: 0.5136
# Epoch 87/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.1570 - iou_score: 0.9091 - val_loss: 1.4011 - val_iou_score: 0.5090
# Epoch 88/100
# 10/10 [==============================] - 3s 312ms/step - loss: 0.1571 - iou_score: 0.9093 - val_loss: 1.4344 - val_iou_score: 0.5040
# Epoch 89/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.1573 - iou_score: 0.9091 - val_loss: 1.3613 - val_iou_score: 0.5125
# Epoch 90/100
# 10/10 [==============================] - 3s 309ms/step - loss: 0.1538 - iou_score: 0.9114 - val_loss: 1.3719 - val_iou_score: 0.5128
# Epoch 91/100
# 10/10 [==============================] - 3s 299ms/step - loss: 0.1533 - iou_score: 0.9121 - val_loss: 1.3721 - val_iou_score: 0.5143
# Epoch 92/100
# 10/10 [==============================] - 3s 299ms/step - loss: 0.1535 - iou_score: 0.9122 - val_loss: 1.4164 - val_iou_score: 0.5085
# Epoch 93/100
# 10/10 [==============================] - 3s 312ms/step - loss: 0.1550 - iou_score: 0.9112 - val_loss: 1.4009 - val_iou_score: 0.5081
# Epoch 94/100
# 10/10 [==============================] - 3s 320ms/step - loss: 0.1509 - iou_score: 0.9130 - val_loss: 1.4444 - val_iou_score: 0.5073
# Epoch 95/100
# 10/10 [==============================] - 3s 299ms/step - loss: 0.1642 - iou_score: 0.9068 - val_loss: 1.4029 - val_iou_score: 0.5088
# Epoch 96/100
# 10/10 [==============================] - 3s 301ms/step - loss: 0.1585 - iou_score: 0.9100 - val_loss: 1.4824 - val_iou_score: 0.5072
# Epoch 97/100
# 10/10 [==============================] - 3s 308ms/step - loss: 0.1576 - iou_score: 0.9101 - val_loss: 1.5212 - val_iou_score: 0.5027
# Epoch 98/100
# 10/10 [==============================] - 3s 311ms/step - loss: 0.1554 - iou_score: 0.9117 - val_loss: 1.4719 - val_iou_score: 0.5046
# Epoch 99/100
# 10/10 [==============================] - 3s 309ms/step - loss: 0.1586 - iou_score: 0.9097 - val_loss: 1.4183 - val_iou_score: 0.5087
# Epoch 100/100
# 10/10 [==============================] - 3s 313ms/step - loss: 0.1549 - iou_score: 0.9115 - val_loss: 1.4403 - val_iou_score: 0.5082

# %%
def plot_result(img_pred, original, valid):
    plt.figure(figsize=(10, 10))
    n = 1
    for index, img in enumerate(img_pred):
        for i in range(3):
            plt.xticks([])
            plt.yticks([])
            plt.grid(False)
            plt.subplot(img_pred.shape[0] , 3, n)
            if i == 0:
                original_img = cv2.resize(original[index], img_size)
                plt.imshow(original_img)
                plt.xlabel("Original ")
            if i == 1:
                result_img = cv2.resize(img, img_size)
                plt.imshow(result_img, cmap=plt.cm.binary)
                plt.xlabel("Result", )
            if i == 2:
                valid_img = cv2.resize(valid[index], img_size)
                plt.imshow(valid_img, cmap=plt.cm.binary)
                plt.xlabel("Expected")
            n += 1

# %%
path_healthy_img = '../dataset/segmentation/healthy/'
path_healthy_val = '../dataset/segmentation/annotation/healthy/'

healthy_img = load_all_imgs(path_healthy_img, img_size, 1)
healthy_val = load_all_imgs(path_healthy_val, img_size, 0)
healthy_pred = model.predict(healthy_img)
# ----- Primeiras 5 Imagens -----
plot_result(healthy_pred[:5], healthy_img[:5], healthy_val[:5])
# ----- Ultimas 5 Imagens -----
plot_result(healthy_pred[-5:], healthy_img[-5:], healthy_val[-5:])
# Out:
# ../dataset/segmentation/healthy/ found 30 img to load
#
# [0]:|||||||||||||||||||||||||||||
# ../dataset/segmentation/annotation/healthy/ found 30 img to load
#
# [0]:|||||||||||||||||||||||||||||
