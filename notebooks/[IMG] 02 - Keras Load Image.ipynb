# %%
# %matplotlib inline

from matplotlib import pyplot as plt
from tensorflow import keras
import numpy as np
from tensorflow.keras.preprocessing.image import load_img

# %%
img = load_img('../dataset/dataset_64x64/healthy-image003-2-roi1-0-1.tif', target_size=(64,64))

# %%
plt.imshow(img)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
img.size
# Out:
# (64, 64)

# %%
img.split()[0]
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x7F2CF0055B80>
