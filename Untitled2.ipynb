# %%
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/{cu_version}/{torch_version}/index.html
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu101/torch1.8.0/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu101/torch1.8.0/index.html
# Requirement already satisfied: mmcv-full in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (1.4.1)
# Requirement already satisfied: numpy in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcv-full) (1.21.4)
# Requirement already satisfied: pyyaml in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcv-full) (6.0)
# Requirement already satisfied: yapf in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcv-full) (0.31.0)
# Requirement already satisfied: Pillow in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcv-full) (8.4.0)
# Requirement already satisfied: addict in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcv-full) (2.4.0)
# Requirement already satisfied: packaging in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcv-full) (21.3)
# Requirement already satisfied: opencv-python>=3 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcv-full) (4.5.4.60)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from packaging->mmcv-full) (3.0.4)

# %%
# !git clone https://github.com/open-mmlab/mmgeneration.git
# %cd mmgeneration
# Out:
# fatal: destination path 'mmgeneration' already exists and is not an empty directory.
# /home/neto/projects/tcc/mmgeneration

# %%
# !pip install -r requirements.txt
# !pip install -v -e .
# Out:
# Requirement already satisfied: mmcls==0.10.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/runtime.txt (line 1)) (0.10.0)
# Requirement already satisfied: numpy in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/runtime.txt (line 2)) (1.21.4)
# Requirement already satisfied: prettytable in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/runtime.txt (line 3)) (2.4.0)
# Requirement already satisfied: scikit-image in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/runtime.txt (line 4)) (0.19.1)
# Requirement already satisfied: scipy in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/runtime.txt (line 5)) (1.7.3)
# Requirement already satisfied: tqdm in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/runtime.txt (line 6)) (4.62.3)
# Requirement already satisfied: yapf in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/runtime.txt (line 7)) (0.31.0)
# Requirement already satisfied: codecov in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/tests.txt (line 1)) (2.1.12)
# Requirement already satisfied: flake8 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/tests.txt (line 2)) (4.0.1)
# Requirement already satisfied: interrogate in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/tests.txt (line 3)) (1.5.0)
# Requirement already satisfied: isort==4.3.21 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/tests.txt (line 4)) (4.3.21)
# Requirement already satisfied: pytest in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/tests.txt (line 5)) (6.2.5)
# Requirement already satisfied: pytest-runner in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from -r requirements/tests.txt (line 6)) (5.3.1)
# Requirement already satisfied: matplotlib in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcls==0.10.0->-r requirements/runtime.txt (line 1)) (3.5.1)
# Requirement already satisfied: wcwidth in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from prettytable->-r requirements/runtime.txt (line 3)) (0.2.5)
# Requirement already satisfied: networkx>=2.2 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->-r requirements/runtime.txt (line 4)) (2.6.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->-r requirements/runtime.txt (line 4)) (8.4.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->-r requirements/runtime.txt (line 4)) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->-r requirements/runtime.txt (line 4)) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->-r requirements/runtime.txt (line 4)) (2021.11.2)
# Requirement already satisfied: imageio>=2.4.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->-r requirements/runtime.txt (line 4)) (2.13.5)
# Requirement already satisfied: coverage in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from codecov->-r requirements/tests.txt (line 1)) (6.2)
# Requirement already satisfied: requests>=2.7.9 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from codecov->-r requirements/tests.txt (line 1)) (2.27.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from flake8->-r requirements/tests.txt (line 2)) (0.6.1)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from flake8->-r requirements/tests.txt (line 2)) (2.8.0)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from flake8->-r requirements/tests.txt (line 2)) (2.4.0)
# Requirement already satisfied: click>=7.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->-r requirements/tests.txt (line 3)) (8.0.3)
# Requirement already satisfied: tabulate in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->-r requirements/tests.txt (line 3)) (0.8.9)
# Requirement already satisfied: colorama in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->-r requirements/tests.txt (line 3)) (0.4.4)
# Requirement already satisfied: attrs in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->-r requirements/tests.txt (line 3)) (21.2.0)
# Requirement already satisfied: py in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->-r requirements/tests.txt (line 3)) (1.11.0)
# Requirement already satisfied: toml in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->-r requirements/tests.txt (line 3)) (0.10.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from pytest->-r requirements/tests.txt (line 5)) (1.0.0)
# Requirement already satisfied: iniconfig in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from pytest->-r requirements/tests.txt (line 5)) (1.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from packaging>=20.0->scikit-image->-r requirements/runtime.txt (line 4)) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.7.9->codecov->-r requirements/tests.txt (line 1)) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.7.9->codecov->-r requirements/tests.txt (line 1)) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.7.9->codecov->-r requirements/tests.txt (line 1)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.7.9->codecov->-r requirements/tests.txt (line 1)) (2021.10.8)
# Requirement already satisfied: cycler>=0.10 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->-r requirements/runtime.txt (line 1)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->-r requirements/runtime.txt (line 1)) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->-r requirements/runtime.txt (line 1)) (4.28.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->-r requirements/runtime.txt (line 1)) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mmcls==0.10.0->-r requirements/runtime.txt (line 1)) (1.16.0)
# Using pip 21.2.4 from /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/pip (python 3.9)
# Obtaining file:///home/neto/projects/tcc/mmgeneration
#     Running command python setup.py egg_info
#     running egg_info
#     creating /tmp/pip-pip-egg-info-t2rjyw_l/mmgen.egg-info
#     writing /tmp/pip-pip-egg-info-t2rjyw_l/mmgen.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-t2rjyw_l/mmgen.egg-info/dependency_links.txt
#     writing requirements to /tmp/pip-pip-egg-info-t2rjyw_l/mmgen.egg-info/requires.txt
#     writing top-level names to /tmp/pip-pip-egg-info-t2rjyw_l/mmgen.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-t2rjyw_l/mmgen.egg-info/SOURCES.txt'
#     reading manifest file '/tmp/pip-pip-egg-info-t2rjyw_l/mmgen.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching 'mmgen/model-index.yml'
#     warning: no files found matching '*.py' under directory 'mmgen/configs'
#     warning: no files found matching '*.yml' under directory 'mmgen/configs'
#     warning: no files found matching '*.sh' under directory 'mmgen/tools'
#     warning: no files found matching '*.py' under directory 'mmgen/tools'
#     adding license file 'LICENSE'
#     adding license file 'LICENSES.md'
#     writing manifest file '/tmp/pip-pip-egg-info-t2rjyw_l/mmgen.egg-info/SOURCES.txt'
# Requirement already satisfied: mmcls==0.10.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (0.10.0)
# Requirement already satisfied: numpy in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (1.21.4)
# Requirement already satisfied: prettytable in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (2.4.0)
# Requirement already satisfied: scikit-image in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (0.19.1)
# Requirement already satisfied: scipy in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (1.7.3)
# Requirement already satisfied: tqdm in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (4.62.3)
# Requirement already satisfied: yapf in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (0.31.0)
# Requirement already satisfied: codecov in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (2.1.12)
# Requirement already satisfied: flake8 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (4.0.1)
# Requirement already satisfied: interrogate in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (1.5.0)
# Requirement already satisfied: isort==4.3.21 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (4.3.21)
# Requirement already satisfied: pytest in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (6.2.5)
# Requirement already satisfied: pytest-runner in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmgen==0.4.0) (5.3.1)
# Requirement already satisfied: matplotlib in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from mmcls==0.10.0->mmgen==0.4.0) (3.5.1)
# Requirement already satisfied: requests>=2.7.9 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from codecov->mmgen==0.4.0) (2.27.0)
# Requirement already satisfied: coverage in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from codecov->mmgen==0.4.0) (6.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.7.9->codecov->mmgen==0.4.0) (2.0.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.7.9->codecov->mmgen==0.4.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.7.9->codecov->mmgen==0.4.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.7.9->codecov->mmgen==0.4.0) (3.3)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from flake8->mmgen==0.4.0) (0.6.1)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from flake8->mmgen==0.4.0) (2.8.0)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from flake8->mmgen==0.4.0) (2.4.0)
# Requirement already satisfied: toml in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->mmgen==0.4.0) (0.10.2)
# Requirement already satisfied: click>=7.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->mmgen==0.4.0) (8.0.3)
# Requirement already satisfied: attrs in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->mmgen==0.4.0) (21.2.0)
# Requirement already satisfied: colorama in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->mmgen==0.4.0) (0.4.4)
# Requirement already satisfied: tabulate in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->mmgen==0.4.0) (0.8.9)
# Requirement already satisfied: py in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from interrogate->mmgen==0.4.0) (1.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->mmgen==0.4.0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->mmgen==0.4.0) (4.28.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->mmgen==0.4.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->mmgen==0.4.0) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->mmgen==0.4.0) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->mmgen==0.4.0) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from matplotlib->mmcls==0.10.0->mmgen==0.4.0) (21.3)
# Requirement already satisfied: six>=1.5 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mmcls==0.10.0->mmgen==0.4.0) (1.16.0)
# Requirement already satisfied: wcwidth in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from prettytable->mmgen==0.4.0) (0.2.5)
# Requirement already satisfied: iniconfig in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from pytest->mmgen==0.4.0) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from pytest->mmgen==0.4.0) (1.0.0)
# Requirement already satisfied: networkx>=2.2 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->mmgen==0.4.0) (2.6.3)
# Requirement already satisfied: imageio>=2.4.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->mmgen==0.4.0) (2.13.5)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->mmgen==0.4.0) (1.2.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from scikit-image->mmgen==0.4.0) (2021.11.2)
# Installing collected packages: mmgen
#   Attempting uninstall: mmgen
#     Found existing installation: mmgen 0.4.0
#     Uninstalling mmgen-0.4.0:
#       Removing file or directory /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/mmgen.egg-link
#       Removing pth entries from /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/easy-install.pth:
#       Removing entry: /home/neto/projects/tcc/mmgeneration
#       Successfully uninstalled mmgen-0.4.0
#   Running setup.py develop for mmgen
#     Running command /home/neto/anaconda3/envs/torch_gpu/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/home/neto/projects/tcc/mmgeneration/setup.py'"'"'; __file__='"'"'/home/neto/projects/tcc/mmgeneration/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' develop --no-deps
#     running develop
#     running egg_info
#     writing mmgen.egg-info/PKG-INFO
#     writing dependency_links to mmgen.egg-info/dependency_links.txt
#     writing requirements to mmgen.egg-info/requires.txt
#     writing top-level names to mmgen.egg-info/top_level.txt
#     reading manifest file 'mmgen.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching 'mmgen/model-index.yml'
#     warning: no files found matching '*.py' under directory 'mmgen/configs'
#     warning: no files found matching '*.yml' under directory 'mmgen/configs'
#     warning: no files found matching '*.sh' under directory 'mmgen/tools'
#     warning: no files found matching '*.py' under directory 'mmgen/tools'
#     adding license file 'LICENSE'
#     adding license file 'LICENSES.md'
#     writing manifest file 'mmgen.egg-info/SOURCES.txt'
#     /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/utils/cpp_extension.py:369: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#       warnings.warn(msg.format('we could not find ninja.'))
#     running build_ext
#     Creating /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/mmgen.egg-link (link to .)
#     Adding mmgen 0.4.0 to easy-install.pth file
#
#     Installed /home/neto/projects/tcc/mmgeneration
# Successfully installed mmgen-0.4.0

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (7.6.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (6.4.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (7.29.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.0.6)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: pexpect>4.3 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: pickleshare in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.0)
# Requirement already satisfied: decorator in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.0)
# Requirement already satisfied: pygments in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (58.0.4)
# Requirement already satisfied: backcall in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.2)
# Requirement already satisfied: python-dateutil>=2.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.6)
# Requirement already satisfied: jinja2 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.2)
# Requirement already satisfied: nbconvert in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: prometheus-client in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.4)
# Requirement already satisfied: argon2-cffi in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.14.6)
# Requirement already satisfied: pycparser in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: bleach in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: defusedxml in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: testpath in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: async-generator in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.10)
# Requirement already satisfied: webencodings in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.4)

# %%
import mmcv
from mmgen.apis import init_model, sample_uncoditional_model

# Specify the path to model config and checkpoint file
config_file = 'configs/styleganv2/stylegan2_c2_ffhq_1024_b4x8.py'
# you can download this checkpoint in advance and use a local file path.
checkpoint_file = 'https://download.openmmlab.com/mmgen/stylegan2/official_weights/stylegan2-church-config-f-official_20210327_172657-1d42b7d1.pth'

device = 'cuda:0'
# init a generatvie
model = init_model(config_file, checkpoint_file, device=device)
# sample images
fake_imgs = sample_uncoditional_model(model, 4)
# Out:
# load checkpoint from http path: https://download.openmmlab.com/mmgen/stylegan2/official_weights/stylegan2-church-config-f-official_20210327_172657-1d42b7d1.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for discriminator.convs.0.0.conv.weight_orig: copying a param with shape torch.Size([128, 3, 1, 1]) from checkpoint, the shape in current model is torch.Size([32, 3, 1, 1]).
# size mismatch for discriminator.convs.0.1.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([32]).
# size mismatch for discriminator.convs.1.conv1.0.conv.weight_orig: copying a param with shape torch.Size([128, 128, 3, 3]) from checkpoint, the shape in current model is torch.Size([32, 32, 3, 3]).
# size mismatch for discriminator.convs.1.conv1.1.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([32]).
# size mismatch for discriminator.convs.1.conv2.1.conv.weight_orig: copying a param with shape torch.Size([256, 128, 3, 3]) from checkpoint, the shape in current model is torch.Size([64, 32, 3, 3]).
# size mismatch for discriminator.convs.1.conv2.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([64]).
# size mismatch for discriminator.convs.1.skip.1.conv.weight_orig: copying a param with shape torch.Size([256, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([64, 32, 1, 1]).
# size mismatch for discriminator.convs.2.conv1.0.conv.weight_orig: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([64, 64, 3, 3]).
# size mismatch for discriminator.convs.2.conv1.1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([64]).
# size mismatch for discriminator.convs.2.conv2.1.conv.weight_orig: copying a param with shape torch.Size([512, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([128, 64, 3, 3]).
# size mismatch for discriminator.convs.2.conv2.2.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([128]).
# size mismatch for discriminator.convs.2.skip.1.conv.weight_orig: copying a param with shape torch.Size([512, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 64, 1, 1]).
# size mismatch for discriminator.convs.3.conv1.0.conv.weight_orig: copying a param with shape torch.Size([512, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([128, 128, 3, 3]).
# size mismatch for discriminator.convs.3.conv1.1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([128]).
# size mismatch for discriminator.convs.3.conv2.1.conv.weight_orig: copying a param with shape torch.Size([512, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 128, 3, 3]).
# size mismatch for discriminator.convs.3.conv2.2.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([256]).
# size mismatch for discriminator.convs.3.skip.1.conv.weight_orig: copying a param with shape torch.Size([512, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([256, 128, 1, 1]).
# size mismatch for discriminator.convs.4.conv1.0.conv.weight_orig: copying a param with shape torch.Size([512, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 256, 3, 3]).
# size mismatch for discriminator.convs.4.conv1.1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([256]).
# size mismatch for discriminator.convs.4.conv2.1.conv.weight_orig: copying a param with shape torch.Size([512, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 256, 3, 3]).
# size mismatch for discriminator.convs.4.skip.1.conv.weight_orig: copying a param with shape torch.Size([512, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 256, 1, 1]).
# missing keys in source state_dict: generator.injected_noise_13, generator.injected_noise_14, generator.injected_noise_15, generator.injected_noise_16, generator.convs.12.conv.weight_orig, generator.convs.12.conv.style_modulation.bias, generator.convs.12.conv.style_modulation.linear.weight_orig, generator.convs.12.conv.blur.kernel, generator.convs.12.noise_injector.weight, generator.convs.12.activate.bias, generator.convs.13.conv.weight_orig, generator.convs.13.conv.style_modulation.bias, generator.convs.13.conv.style_modulation.linear.weight_orig, generator.convs.13.noise_injector.weight, generator.convs.13.activate.bias, generator.convs.14.conv.weight_orig, generator.convs.14.conv.style_modulation.bias, generator.convs.14.conv.style_modulation.linear.weight_orig, generator.convs.14.conv.blur.kernel, generator.convs.14.noise_injector.weight, generator.convs.14.activate.bias, generator.convs.15.conv.weight_orig, generator.convs.15.conv.style_modulation.bias, generator.convs.15.conv.style_modulation.linear.weight_orig, generator.convs.15.noise_injector.weight, generator.convs.15.activate.bias, generator.to_rgbs.6.bias, generator.to_rgbs.6.upsample.kernel, generator.to_rgbs.6.conv.weight_orig, generator.to_rgbs.6.conv.style_modulation.bias, generator.to_rgbs.6.conv.style_modulation.linear.weight_orig, generator.to_rgbs.7.bias, generator.to_rgbs.7.upsample.kernel, generator.to_rgbs.7.conv.weight_orig, generator.to_rgbs.7.conv.style_modulation.bias, generator.to_rgbs.7.conv.style_modulation.linear.weight_orig, discriminator.convs.7.conv1.0.conv.weight_orig, discriminator.convs.7.conv1.1.bias, discriminator.convs.7.conv2.0.kernel, discriminator.convs.7.conv2.1.conv.weight_orig, discriminator.convs.7.conv2.2.bias, discriminator.convs.7.skip.0.kernel, discriminator.convs.7.skip.1.conv.weight_orig, discriminator.convs.8.conv1.0.conv.weight_orig, discriminator.convs.8.conv1.1.bias, discriminator.convs.8.conv2.0.kernel, discriminator.convs.8.conv2.1.conv.weight_orig, discriminator.convs.8.conv2.2.bias, discriminator.convs.8.skip.0.kernel, discriminator.convs.8.skip.1.conv.weight_orig, generator_ema.injected_noise_13, generator_ema.injected_noise_14, generator_ema.injected_noise_15, generator_ema.injected_noise_16, generator_ema.convs.12.conv.weight_orig, generator_ema.convs.12.conv.style_modulation.bias, generator_ema.convs.12.conv.style_modulation.linear.weight_orig, generator_ema.convs.12.conv.blur.kernel, generator_ema.convs.12.noise_injector.weight, generator_ema.convs.12.activate.bias, generator_ema.convs.13.conv.weight_orig, generator_ema.convs.13.conv.style_modulation.bias, generator_ema.convs.13.conv.style_modulation.linear.weight_orig, generator_ema.convs.13.noise_injector.weight, generator_ema.convs.13.activate.bias, generator_ema.convs.14.conv.weight_orig, generator_ema.convs.14.conv.style_modulation.bias, generator_ema.convs.14.conv.style_modulation.linear.weight_orig, generator_ema.convs.14.conv.blur.kernel, generator_ema.convs.14.noise_injector.weight, generator_ema.convs.14.activate.bias, generator_ema.convs.15.conv.weight_orig, generator_ema.convs.15.conv.style_modulation.bias, generator_ema.convs.15.conv.style_modulation.linear.weight_orig, generator_ema.convs.15.noise_injector.weight, generator_ema.convs.15.activate.bias, generator_ema.to_rgbs.6.bias, generator_ema.to_rgbs.6.upsample.kernel, generator_ema.to_rgbs.6.conv.weight_orig, generator_ema.to_rgbs.6.conv.style_modulation.bias, generator_ema.to_rgbs.6.conv.style_modulation.linear.weight_orig, generator_ema.to_rgbs.7.bias, generator_ema.to_rgbs.7.upsample.kernel, generator_ema.to_rgbs.7.conv.weight_orig, generator_ema.to_rgbs.7.conv.style_modulation.bias, generator_ema.to_rgbs.7.conv.style_modulation.linear.weight_orig
# 2022-01-04 21:25:09,104 - mmgen - INFO - Switch to evaluation style mode: single
# 2022-01-04 21:25:09,105 - mmgen - INFO - Switch to evaluation style mode: single

# %%
fake_imgs = (fake_imgs[:, [2, 1, 0]] + 1.) / 2.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.imshow(fake_imgs[1].permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig, axs = plt.subplots(2, 2)
cnt = 0
for i in range(2):
    for j in range(2):
        img = fake_imgs[cnt].permute(1, 2, 0)
        axs[i, j].imshow(img)
        axs[i, j].axis('off')
        cnt += 1
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import mmcv
from mmgen.apis import init_model, sample_conditional_model

# Specify the path to model config and checkpoint file
config_file = 'configs/sagan/sagan_128_woReLUinplace_noaug_bigGAN_Glr-1e-4_Dlr-4e-4_ndisc1_imagenet1k_b32x8.py'
# you can download this checkpoint in advance and use a local file path.
checkpoint_file = 'https://download.openmmlab.com/mmgen/sagan/sagan_128_woReLUinplace_noaug_bigGAN_imagenet1k_b32x8_Glr1e-4_Dlr-4e-4_ndisc1_20210818_210232-3f5686af.pth'

device = 'cuda:0'
# init a generatvie
model = init_model(config_file, checkpoint_file, device=device)
# sample images with random label
fake_imgs = sample_conditional_model(model, 4)
# Out:
# /home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/mmcv/cnn/bricks/conv_module.py:150: UserWarning: Unnecessary conv bias before batch/instance norm
#   warnings.warn(
# load checkpoint from http path: https://download.openmmlab.com/mmgen/sagan/sagan_128_woReLUinplace_noaug_bigGAN_imagenet1k_b32x8_Glr1e-4_Dlr-4e-4_ndisc1_20210818_210232-3f5686af.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: generator.conv_blocks.4.theta.conv.weight_orig, generator.conv_blocks.4.theta.conv.weight_u, generator.conv_blocks.4.theta.conv.weight_v, generator.conv_blocks.4.phi.conv.weight_orig, generator.conv_blocks.4.phi.conv.weight_u, generator.conv_blocks.4.phi.conv.weight_v, generator.conv_blocks.4.g.conv.weight_orig, generator.conv_blocks.4.g.conv.weight_u, generator.conv_blocks.4.g.conv.weight_v, generator.conv_blocks.4.o.conv.weight_orig, generator.conv_blocks.4.o.conv.weight_u, generator.conv_blocks.4.o.conv.weight_v, discriminator.conv_blocks.0.theta.conv.weight_orig, discriminator.conv_blocks.0.theta.conv.weight_u, discriminator.conv_blocks.0.theta.conv.weight_v, discriminator.conv_blocks.0.phi.conv.weight_orig, discriminator.conv_blocks.0.phi.conv.weight_u, discriminator.conv_blocks.0.phi.conv.weight_v, discriminator.conv_blocks.0.g.conv.weight_orig, discriminator.conv_blocks.0.g.conv.weight_u, discriminator.conv_blocks.0.g.conv.weight_v, discriminator.conv_blocks.0.o.conv.weight_orig, discriminator.conv_blocks.0.o.conv.weight_u, discriminator.conv_blocks.0.o.conv.weight_v, generator_ema.conv_blocks.4.theta.conv.weight_orig, generator_ema.conv_blocks.4.theta.conv.weight_u, generator_ema.conv_blocks.4.theta.conv.weight_v, generator_ema.conv_blocks.4.phi.conv.weight_orig, generator_ema.conv_blocks.4.phi.conv.weight_u, generator_ema.conv_blocks.4.phi.conv.weight_v, generator_ema.conv_blocks.4.g.conv.weight_orig, generator_ema.conv_blocks.4.g.conv.weight_u, generator_ema.conv_blocks.4.g.conv.weight_v, generator_ema.conv_blocks.4.o.conv.weight_orig, generator_ema.conv_blocks.4.o.conv.weight_u, generator_ema.conv_blocks.4.o.conv.weight_v
#
# missing keys in source state_dict: generator.conv_blocks.4.theta.conv.weight, generator.conv_blocks.4.theta.conv.u0, generator.conv_blocks.4.theta.conv.sv0, generator.conv_blocks.4.phi.conv.weight, generator.conv_blocks.4.phi.conv.u0, generator.conv_blocks.4.phi.conv.sv0, generator.conv_blocks.4.g.conv.weight, generator.conv_blocks.4.g.conv.u0, generator.conv_blocks.4.g.conv.sv0, generator.conv_blocks.4.o.conv.weight, generator.conv_blocks.4.o.conv.u0, generator.conv_blocks.4.o.conv.sv0, discriminator.conv_blocks.0.theta.conv.weight, discriminator.conv_blocks.0.theta.conv.u0, discriminator.conv_blocks.0.theta.conv.sv0, discriminator.conv_blocks.0.phi.conv.weight, discriminator.conv_blocks.0.phi.conv.u0, discriminator.conv_blocks.0.phi.conv.sv0, discriminator.conv_blocks.0.g.conv.weight, discriminator.conv_blocks.0.g.conv.u0, discriminator.conv_blocks.0.g.conv.sv0, discriminator.conv_blocks.0.o.conv.weight, discriminator.conv_blocks.0.o.conv.u0, discriminator.conv_blocks.0.o.conv.sv0, generator_ema.conv_blocks.4.theta.conv.weight, generator_ema.conv_blocks.4.theta.conv.u0, generator_ema.conv_blocks.4.theta.conv.sv0, generator_ema.conv_blocks.4.phi.conv.weight, generator_ema.conv_blocks.4.phi.conv.u0, generator_ema.conv_blocks.4.phi.conv.sv0, generator_ema.conv_blocks.4.g.conv.weight, generator_ema.conv_blocks.4.g.conv.u0, generator_ema.conv_blocks.4.g.conv.sv0, generator_ema.conv_blocks.4.o.conv.weight, generator_ema.conv_blocks.4.o.conv.u0, generator_ema.conv_blocks.4.o.conv.sv0

# %%
fake_imgs = (fake_imgs[:, [2, 1, 0]] + 1.) / 2.

# %%
fig, axs = plt.subplots(2, 2)
cnt = 0
for i in range(2):
    for j in range(2):
        img = fake_imgs[cnt].permute(1, 2, 0)
        axs[i, j].imshow(img)
        axs[i, j].axis('off')
        cnt += 1

# %%
# sample images with the same label
fake_imgs = sample_conditional_model(model, 4, label=0)
fake_imgs = (fake_imgs[:, [2, 1, 0]] + 1.) / 2.
fig, axs = plt.subplots(2, 2)
cnt = 0
for i in range(2):
    for j in range(2):
        img = fake_imgs[cnt].permute(1, 2, 0)
        axs[i, j].imshow(img)
        axs[i, j].axis('off')
        cnt += 1

# %%
# sample images with specific labels
fake_imgs = sample_conditional_model(model, 4, label=[0, 1, 2, 3])
fake_imgs = (fake_imgs[:, [2, 1, 0]] + 1.) / 2.
fig, axs = plt.subplots(2, 2)
cnt = 0
for i in range(2):
    for j in range(2):
        img = fake_imgs[cnt].permute(1, 2, 0)
        axs[i, j].imshow(img)
        axs[i, j].axis('off')
        cnt += 1

# %%
import mmcv

from mmgen.apis import init_model, sample_img2img_model

# Specify the path to model config and checkpoint file
config_file = 'configs/pix2pix/pix2pix_vanilla_unet_bn_wo_jitter_flip_edges2shoes_b1x4_190k.py'
# you can download this checkpoint in advance and use a local file path.
checkpoint_file = 'https://download.openmmlab.com/mmgen/pix2pix/refactor/pix2pix_vanilla_unet_bn_wo_jitter_flip_1x4_186840_edges2shoes_convert-bgr_20210902_170902-0c828552.pth'
# Specify the path to image you want to translate
image_path = 'tests/data/paired/test/33_AB.jpg'
device = 'cuda:0'
# init a generatvie
model = init_model(config_file, checkpoint_file, device=device)
# translate a single image
translated_image = sample_img2img_model(model, image_path, target_domain='photo')
# Out:
# load checkpoint from http path: https://download.openmmlab.com/mmgen/pix2pix/refactor/pix2pix_vanilla_unet_bn_wo_jitter_flip_1x4_186840_edges2shoes_convert-bgr_20210902_170902-0c828552.pth

# %%
translated_image = (translated_image[:, [2, 1, 0]] + 1.) / 2.

# %%
plt.imshow(translated_image[0].permute(1,2,0))

# %%
# %cd mmgeneration
# Out:
# /home/neto/projects/tcc/mmgeneration

# %%
# !python demo/unconditional_demo.py "configs/styleganv2/stylegan2_c2_ffhq_1024_b4x8.py" "https://download.openmmlab.com/mmgen/stylegan2/official_weights/stylegan2-church-config-f-official_20210327_172657-1d42b7d1.pth" --num-samples=4 --nrow=4
# Out:
# load checkpoint from http path: https://download.openmmlab.com/mmgen/stylegan2/official_weights/stylegan2-church-config-f-official_20210327_172657-1d42b7d1.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for discriminator.convs.0.0.conv.weight_orig: copying a param with shape torch.Size([128, 3, 1, 1]) from checkpoint, the shape in current model is torch.Size([32, 3, 1, 1]).
# size mismatch for discriminator.convs.0.1.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([32]).
# size mismatch for discriminator.convs.1.conv1.0.conv.weight_orig: copying a param with shape torch.Size([128, 128, 3, 3]) from checkpoint, the shape in current model is torch.Size([32, 32, 3, 3]).
# size mismatch for discriminator.convs.1.conv1.1.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([32]).
# size mismatch for discriminator.convs.1.conv2.1.conv.weight_orig: copying a param with shape torch.Size([256, 128, 3, 3]) from checkpoint, the shape in current model is torch.Size([64, 32, 3, 3]).
# size mismatch for discriminator.convs.1.conv2.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([64]).
# size mismatch for discriminator.convs.1.skip.1.conv.weight_orig: copying a param with shape torch.Size([256, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([64, 32, 1, 1]).
# size mismatch for discriminator.convs.2.conv1.0.conv.weight_orig: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([64, 64, 3, 3]).
# size mismatch for discriminator.convs.2.conv1.1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([64]).
# size mismatch for discriminator.convs.2.conv2.1.conv.weight_orig: copying a param with shape torch.Size([512, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([128, 64, 3, 3]).
# size mismatch for discriminator.convs.2.conv2.2.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([128]).
# size mismatch for discriminator.convs.2.skip.1.conv.weight_orig: copying a param with shape torch.Size([512, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 64, 1, 1]).
# size mismatch for discriminator.convs.3.conv1.0.conv.weight_orig: copying a param with shape torch.Size([512, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([128, 128, 3, 3]).
# size mismatch for discriminator.convs.3.conv1.1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([128]).
# size mismatch for discriminator.convs.3.conv2.1.conv.weight_orig: copying a param with shape torch.Size([512, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 128, 3, 3]).
# size mismatch for discriminator.convs.3.conv2.2.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([256]).
# size mismatch for discriminator.convs.3.skip.1.conv.weight_orig: copying a param with shape torch.Size([512, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([256, 128, 1, 1]).
# size mismatch for discriminator.convs.4.conv1.0.conv.weight_orig: copying a param with shape torch.Size([512, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 256, 3, 3]).
# size mismatch for discriminator.convs.4.conv1.1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([256]).
# size mismatch for discriminator.convs.4.conv2.1.conv.weight_orig: copying a param with shape torch.Size([512, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 256, 3, 3]).
# size mismatch for discriminator.convs.4.skip.1.conv.weight_orig: copying a param with shape torch.Size([512, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 256, 1, 1]).
# missing keys in source state_dict: generator.injected_noise_13, generator.injected_noise_14, generator.injected_noise_15, generator.injected_noise_16, generator.convs.12.conv.weight_orig, generator.convs.12.conv.style_modulation.bias, generator.convs.12.conv.style_modulation.linear.weight_orig, generator.convs.12.conv.blur.kernel, generator.convs.12.noise_injector.weight, generator.convs.12.activate.bias, generator.convs.13.conv.weight_orig, generator.convs.13.conv.style_modulation.bias, generator.convs.13.conv.style_modulation.linear.weight_orig, generator.convs.13.noise_injector.weight, generator.convs.13.activate.bias, generator.convs.14.conv.weight_orig, generator.convs.14.conv.style_modulation.bias, generator.convs.14.conv.style_modulation.linear.weight_orig, generator.convs.14.conv.blur.kernel, generator.convs.14.noise_injector.weight, generator.convs.14.activate.bias, generator.convs.15.conv.weight_orig, generator.convs.15.conv.style_modulation.bias, generator.convs.15.conv.style_modulation.linear.weight_orig, generator.convs.15.noise_injector.weight, generator.convs.15.activate.bias, generator.to_rgbs.6.bias, generator.to_rgbs.6.upsample.kernel, generator.to_rgbs.6.conv.weight_orig, generator.to_rgbs.6.conv.style_modulation.bias, generator.to_rgbs.6.conv.style_modulation.linear.weight_orig, generator.to_rgbs.7.bias, generator.to_rgbs.7.upsample.kernel, generator.to_rgbs.7.conv.weight_orig, generator.to_rgbs.7.conv.style_modulation.bias, generator.to_rgbs.7.conv.style_modulation.linear.weight_orig, discriminator.convs.7.conv1.0.conv.weight_orig, discriminator.convs.7.conv1.1.bias, discriminator.convs.7.conv2.0.kernel, discriminator.convs.7.conv2.1.conv.weight_orig, discriminator.convs.7.conv2.2.bias, discriminator.convs.7.skip.0.kernel, discriminator.convs.7.skip.1.conv.weight_orig, discriminator.convs.8.conv1.0.conv.weight_orig, discriminator.convs.8.conv1.1.bias, discriminator.convs.8.conv2.0.kernel, discriminator.convs.8.conv2.1.conv.weight_orig, discriminator.convs.8.conv2.2.bias, discriminator.convs.8.skip.0.kernel, discriminator.convs.8.skip.1.conv.weight_orig, generator_ema.injected_noise_13, generator_ema.injected_noise_14, generator_ema.injected_noise_15, generator_ema.injected_noise_16, generator_ema.convs.12.conv.weight_orig, generator_ema.convs.12.conv.style_modulation.bias, generator_ema.convs.12.conv.style_modulation.linear.weight_orig, generator_ema.convs.12.conv.blur.kernel, generator_ema.convs.12.noise_injector.weight, generator_ema.convs.12.activate.bias, generator_ema.convs.13.conv.weight_orig, generator_ema.convs.13.conv.style_modulation.bias, generator_ema.convs.13.conv.style_modulation.linear.weight_orig, generator_ema.convs.13.noise_injector.weight, generator_ema.convs.13.activate.bias, generator_ema.convs.14.conv.weight_orig, generator_ema.convs.14.conv.style_modulation.bias, generator_ema.convs.14.conv.style_modulation.linear.weight_orig, generator_ema.convs.14.conv.blur.kernel, generator_ema.convs.14.noise_injector.weight, generator_ema.convs.14.activate.bias, generator_ema.convs.15.conv.weight_orig, generator_ema.convs.15.conv.style_modulation.bias, generator_ema.convs.15.conv.style_modulation.linear.weight_orig, generator_ema.convs.15.noise_injector.weight, generator_ema.convs.15.activate.bias, generator_ema.to_rgbs.6.bias, generator_ema.to_rgbs.6.upsample.kernel, generator_ema.to_rgbs.6.conv.weight_orig, generator_ema.to_rgbs.6.conv.style_modulation.bias, generator_ema.to_rgbs.6.conv.style_modulation.linear.weight_orig, generator_ema.to_rgbs.7.bias, generator_ema.to_rgbs.7.upsample.kernel, generator_ema.to_rgbs.7.conv.weight_orig, generator_ema.to_rgbs.7.conv.style_modulation.bias, generator_ema.to_rgbs.7.conv.style_modulation.linear.weight_orig
#
# 2022-01-04 21:23:52,948 - mmgen - INFO - Switch to evaluation style mode: single
# 2022-01-04 21:23:52,948 - mmgen - INFO - Switch to evaluation style mode: single

# %%
import mmcv
from mmcv import Config
from mmgen.apis import init_model, sample_uncoditional_model

# Specify the path to model config and checkpoint file
config_file = 'configs/dcgan/dcgan.py'
# you can download this checkpoint in advance and use a local file path.
# checkpoint_file = 'https://download.openmmlab.com/mmgen/pix2pix/refactor/pix2pix_vanilla_unet_bn_wo_jitter_flip_1x4_186840_edges2shoes_convert-bgr_20210902_170902-0c828552.pth'
# Specify the path to image you want to translate
image_path = 'data/dysplasia'
device = 'cuda:0'
# init a generatvie
# cfg = Config.fromfile('configs/pspnet/pspnet_r50-d8_512x1024_40k_cityscapes.py')
cfg = Config.fromfile(config_file)
model = init_model(config_file, device=device)
# translate a single image
translated_image = sample_uncoditional_model(model, 4)

# %%
translated_image.shape
# Out:
# torch.Size([4, 3, 128, 128])

# %%
translated_image = (translated_image[:, [2, 1, 0]] + 1.) / 2.

# %%
fig, axs = plt.subplots(2, 2)
cnt = 0
for i in range(2):
    for j in range(2):
        img = translated_image[cnt].permute(1, 2, 0)
        axs[i, j].imshow(img)
        axs[i, j].axis('off')
        cnt += 1
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fd4f813eca0>
# Traceback (most recent call last):
#   File "/home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1324, in __del__
#     self._shutdown_workers()
#   File "/home/neto/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1297, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/neto/anaconda3/envs/torch_gpu/lib/python3.9/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/neto/anaconda3/envs/torch_gpu/lib/python3.9/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/neto/anaconda3/envs/torch_gpu/lib/python3.9/multiprocessing/connection.py", line 936, in wait
#     ready = selector.select(timeout)
#   File "/home/neto/anaconda3/envs/torch_gpu/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:

# %%
from mmgen.apis import train_model
from mmgen.datasets import build_dataset

# %%
# `samples_per_gpu` and `imgs_root` need to be set.

cfg.work_dir = './work_dirs/tutorial'

cfg.seed = 0
cfg.gpu_ids = range(1)

# %%
datasets = [build_dataset(cfg.data['train'])]
# Out:
# 2022-01-04 23:44:22,943 - mmgen - INFO - dataset_name: <class 'mmgen.datasets.unconditional_image_dataset.UnconditionalImageDataset'>, total 192 images in imgs_root: data/dysplasia/train

# %%
train_model(model,datasets,cfg)
# Out:
# 2022-01-04 23:44:25,386 - mmgen - INFO - Start running, host: neto@Matheus-Neto, work_dir: /home/neto/projects/tcc/mmgeneration/work_dirs/tutorial
# 2022-01-04 23:44:25,386 - mmgen - INFO - workflow: [('train', 10000)], max: 300002 iters
# 2022-01-04 23:44:25,387 - mmgen - INFO - Checkpoints will be saved to ./work_dirs/tutorial/ckpt/tutorial by HardDiskBackend.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_19593/3827685828.py in <module>
# ----> 1 train_model(model,datasets,cfg)
#
# ~/projects/tcc/mmgeneration/mmgen/apis/train.py in train_model(model, dataset, cfg, distributed, validate, timestamp, meta)
#     197     elif cfg.load_from:
#     198         runner.load_checkpoint(cfg.load_from)
# --> 199     runner.run(data_loaders, cfg.workflow, cfg.total_iters)
#
# ~/projects/tcc/mmgeneration/mmgen/core/runners/dynamic_iterbased_runner.py in run(self, data_loaders, workflow, max_iters, **kwargs)
#     283                     if mode == 'train' and self.iter >= self._max_iters:
#     284                         break
# --> 285                     iter_runner(iter_loaders[i], **kwargs)
#     286
#     287         time.sleep(1)  # wait for some hooks like loggers to finish
#
# ~/projects/tcc/mmgeneration/mmgen/core/runners/dynamic_iterbased_runner.py in train(self, data_loader, **kwargs)
#     213             kwargs.update(dict(use_apex_amp=True))
#     214
# --> 215         outputs = self.model.train_step(data_batch, self.optimizer, **kwargs)
#     216
#     217         # the loss scaler should be updated after ``train_step``
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/mmcv/parallel/data_parallel.py in train_step(self, *inputs, **kwargs)
#      73
#      74         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
# ---> 75         return self.module.train_step(*inputs[0], **kwargs[0])
#      76
#      77     def val_step(self, *inputs, **kwargs):
#
# ~/projects/tcc/mmgeneration/mmgen/models/gans/static_unconditional_gan.py in train_step(self, data_batch, optimizer, ddp_reducer, loss_scaler, use_apex_amp, running_status)
#     173         # disc pred for fake imgs and real_imgs
#     174         disc_pred_fake = self.discriminator(fake_imgs)
# --> 175         disc_pred_real = self.discriminator(real_imgs)
#     176         # get data dict to compute losses for disc
#     177         data_dict_ = dict(
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/projects/tcc/mmgeneration/mmgen/models/architectures/dcgan/generator_discriminator.py in forward(self, x)
#     286
#     287         n = x.shape[0]
# --> 288         x = self.downsamples(x)
#     289         x = self.output_layer(x)
#     290
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/mmcv/cnn/bricks/conv_module.py in forward(self, x, activate, norm)
#     199                 if self.with_explicit_padding:
#     200                     x = self.padding_layer(x)
# --> 201                 x = self.conv(x)
#     202             elif layer == 'norm' and norm and self.with_norm:
#     203                 x = self.norm(x)
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/torch_gpu/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     393                             weight, bias, self.stride,
#     394                             _pair(0), self.dilation, self.groups)
# --> 395         return F.conv2d(input, weight, bias, self.stride,
#     396                         self.padding, self.dilation, self.groups)
#     397
#
# RuntimeError: CUDA out of memory. Tried to allocate 64.00 MiB (GPU 0; 3.94 GiB total capacity; 2.82 GiB already allocated; 30.31 MiB free; 2.91 GiB reserved in total by PyTorch)
